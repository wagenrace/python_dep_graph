# %%
import os
import json

import pandas as pd
from fastapi import FastAPI
from py2neo import Graph

# %%
url = os.environ.get("NEO4J_URL", "bolt://localhost:7687")
user = os.environ.get("NEO4J_USER", "neo4j")
pswd = os.environ.get("NEO4J_PSWD", "password")
graph = Graph(url, auth=(user, pswd))

csv_file_name = "results.csv"

# %%
response = graph.run(
    f"""
MATCH (n:package)
WHERE n.license CONTAINS "GNU general public license" OR n.license CONTAINS "GNU Affero general public license"

MATCH (n)<-[:DEPENDS_ON*1..]-(m)
WHERE NOT m.license CONTAINS "GNU general public license" AND NOT m.license CONTAINS "GNU Affero general public license"
RETURN m.name as name, m.license AS license, collect( DISTINCT n.name) as GPL_dependencies ORDER BY license
    """
).data()
all_miss_matches = pd.DataFrame(response)
all_miss_matches.to_csv(csv_file_name, index=False)

# %%
all_miss_matches = pd.read_csv(csv_file_name)
all_miss_matches
# Out:
#                               name  \
# 0   apache-airflow-providers-mysql
# 1                            jiwer
# 2                       optbinning
# 3                            ropwr
# 4                     rpaframework
# 5             rpaframework-dialogs
# 6                         causalml
# 7                     cmreshandler
# 8                              dvc
# 9                         dvc-http
# 10                        tidal-dl
# 11                           cvxpy
# 12                python-dev-tools
# 13                     cartoframes
# 14                    django-filer
# 15                      weasyprint
# 16                    cibuildwheel
# 17                        oletools
# 18                        workflow
# 19                           rtfde
# 20                  sphinx-autoapi
# 21                       uszipcode
# 22                        molecule
# 23                 molecule-docker
# 24                     workalendar
# 25        wemake-python-styleguide
# 26                   pylint-quotes
# 27                   pylint-gitlab
# 28                   flake8-pylint
# 29                   pytest-pylint
# 30                          spotdl
# 31                   pandas-dedupe
# 32                     pyphonetics
# 33                    fortnitesave
# 34                       office365
# 35                     pymiscutils
# 36                      pysubtypes
# 37                       pathmagic
# 38                       pyiotools
# 39                           mysql
# 40                          os-sys
# 41                       pythongui
# 42                        textstat
# 43                  auto-py-to-exe
# 44                          pyxlsx
# 45                   pylint-pytest
# 46                           aigpy
# 47                        textract
# 48                          yt-dlp
# 49            amundsen-databuilder
# 50                    glean-parser
# 51                          imdbpy
# 52                    email-master
# 53                 robocorp-dialog
#
#                                           license  \
# 0                                  Apache license
# 1                                  Apache license
# 2                                  Apache license
# 3                                  Apache license
# 4                                  Apache license
# 5                                  Apache license
# 6                                  Apache license
# 7                                  Apache license
# 8                              Apache license 2.0
# 9                              Apache license 2.0
# 10                             Apache license 2.0
# 11                             Apache license 2.0
# 12                                    BSD license
# 13                                    BSD license
# 14                                    BSD license
# 15                                    BSD license
# 16                                    BSD license
# 17                                    BSD license
# 18                                    BSD license
# 19  GNU lesser general public license v3 (lgplv3)
# 20                                    MIT license
# 21                                    MIT license
# 22                                    MIT license
# 23                                    MIT license
# 24                                    MIT license
# 25                                    MIT license
# 26                                    MIT license
# 27                                    MIT license
# 28                                    MIT license
# 29                                    MIT license
# 30                                    MIT license
# 31                                    MIT license
# 32                                    MIT license
# 33                                    MIT license
# 34                                    MIT license
# 35                                    MIT license
# 36                                    MIT license
# 37                                    MIT license
# 38                                    MIT license
# 39                                    MIT license
# 40                                    MIT license
# 41                                    MIT license
# 42                                    MIT license
# 43                                    MIT license
# 44                                    MIT license
# 45                                    MIT license
# 46                                    MIT license
# 47                                    MIT license
# 48                                  Public Domain
# 49                                        UNKNOWN
# 50                                        UNKNOWN
# 51                                        UNKNOWN
# 52                                        UNKNOWN
# 53                      other/proprietary license
#
#                                      GPL_dependencies
# 0           ['mysql-connector-python', 'mysqlclient']
# 1                                     ['levenshtein']
# 2                                            ['ecos']
# 3                                            ['ecos']
# 4                          ['pyqt5', 'pyqtwebengine']
# 5                          ['pyqt5', 'pyqtwebengine']
# 6                                           ['pygam']
# 7                                            ['enum']
# 8                                        ['grandalf']
# 9                                        ['grandalf']
# 10                                        ['mutagen']
# 11                                           ['ecos']
# 12  ['pylint', 'flake8-isort', 'flake8-builtins', ...
# 13                                      ['unidecode']
# 14                                      ['unidecode']
# 15                                         ['pyphen']
# 16                                        ['bashlex']
# 17                                       ['pcodedmp']
# 18                                     ['autosemver']
# 19                                       ['pcodedmp']
# 20                                      ['unidecode']
# 21                                     ['fuzzywuzzy']
# 22                                 ['ansible-compat']
# 23                                 ['ansible-compat']
# 24                                      ['lunardate']
# 25                                   ['flake8-isort']
# 26                                         ['pylint']
# 27                                         ['pylint']
# 28                                         ['pylint']
# 29                                         ['pylint']
# 30                           ['unidecode', 'mutagen']
# 31                                      ['unidecode']
# 32                                      ['unidecode']
# 33                                     ['aioconsole']
# 34  ['fuzzywuzzy', 'pyqt5', 'gender-guesser', 'cur...
# 35         ['fuzzywuzzy', 'gender-guesser', 'cursor']
# 36                                     ['fuzzywuzzy']
# 37                                     ['fuzzywuzzy']
# 38  ['fuzzywuzzy', 'pyqt5', 'gender-guesser', 'cur...
# 39                                    ['mysqlclient']
# 40                 ['mysql-connector', 'pyinstaller']
# 41                 ['mysql-connector', 'pyinstaller']
# 42                                         ['pyphen']
# 43                                    ['pyinstaller']
# 44                                          ['pycel']
# 45                                         ['pylint']
# 46                                        ['mutagen']
# 47                        ['extract-msg', 'pcodedmp']
# 48                                        ['mutagen']
# 49                                      ['unidecode']
# 50                                       ['yamllint']
# 51                                     ['cinemagoer']
# 52                        ['extract-msg', 'pcodedmp']
# 53                         ['pyqt5', 'pyqtwebengine']

# %%
all_miss_matches.license.value_counts().to_dict()
# Out:
# {'MIT license': 28,
#  'Apache license': 8,
#  'BSD license': 7,
#  'Apache license 2.0': 4,
#  'UNKNOWN': 4,
#  'GNU lesser general public license v3 (lgplv3)': 1,
#  'Public Domain': 1,
#  'other/proprietary license': 1}
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
